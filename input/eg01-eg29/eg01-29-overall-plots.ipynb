# %% [markdown]
# # EG01-29
# ** Deployment Plot **
#
# These plots were used in the DDCA Journal Article (https://github.com/arfc/2019-ddca-journal-article), Demonstration of Demand Driven Deployment Capabilities in Cyclus Global Presentation (https://github.com/arfc/2019-chee-global), and the DDCA final quarterly report (https://github.com/arfc/ddca_numerical_exp).
#
# To generate the plots in this Jupyter Notebook, you must go to the ARFC Fuel-Cycle Box (fuel-cycle/cyclus_output/d3ploy-transition-scenarios/eg01-eg29) and download the following sqlite file:
# * eg01-eg29-flatpower-d3ploy-buffer0-S1-poly.sqlite

# %%
import sys 
sys.path.insert(0, '../../scripts/')
import transition_plots as tp

# %%
sqlite29= 'eg01-eg29-flatpower-d3ploy-buffer0-S1-poly.sqlite'
all_agents29 = tp.format_agent_dict(sqlite29)
tp.plot_agents(all_agents29,name='eg29-stack')
